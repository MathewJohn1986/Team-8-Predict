# %%
#import libraries
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import catboost as cb
import pickle
from scipy.stats import norm
from scipy.stats import zscore
from mpl_toolkits.mplot3d import Axes3D
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler,MinMaxScaler,PolynomialFeatures,RobustScaler
from scipy import stats
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, RidgeCV, ElasticNet, LassoCV, LassoLarsCV
from sklearn.model_selection import GridSearchCV,KFold,RandomizedSearchCV,StratifiedKFold,cross_val_score
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,BaggingRegressor,ExtraTreesRegressor
from sklearn.linear_model import LassoCV,RidgeCV,ElasticNetCV
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# load train set and test set
df = pd.read_csv("https://raw.githubusercontent.com/MathewJohn1986/Team-8-Predict/main/df-train_set.csv")

# %%
test = pd.read_csv('https://raw.githubusercontent.com/MathewJohn1986/Team-8-Predict/main/df-test_set.csv')

# %%
#filtering out the Apple golden delicious
apples_df_filter = df[df['Commodities']== 'APPLE GOLDEN DELICIOUS']
apples_df = apples_df_filter.copy()
apples_df.head()
# Out:
#                 Province Container Size_Grade  Weight_Kg  \
# 1                   CAPE     M4183         1L       18.3
# 7                   CAPE     JG110         2M       11.0
# 24  W.CAPE-BERGRIVER ETC     JE090         2S        9.0
# 40                  CAPE     M4183         1S       18.3
# 69          EASTERN CAPE     IA400         1S      400.0
#
#                Commodities        Date  Low_Price  High_Price  Sales_Total  \
# 1   APPLE GOLDEN DELICIOUS  2020-09-09      150.0       170.0      51710.0
# 7   APPLE GOLDEN DELICIOUS  2020-04-14       50.0        50.0      16000.0
# 24  APPLE GOLDEN DELICIOUS  2020-04-16       55.0        55.0        990.0
# 40  APPLE GOLDEN DELICIOUS  2020-05-04       80.0       120.0      32020.0
# 69  APPLE GOLDEN DELICIOUS  2020-09-28     1800.0      1800.0       1800.0
#
#     Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand  avg_price_per_kg
# 1              332         6075.6            822              8.51
# ...

# %%
test.head()
# Out:
#    Index              Province Container Size_Grade  Weight_Kg  \
# 0      1  W.CAPE-BERGRIVER ETC     EC120         1M       12.0
# 1      2  W.CAPE-BERGRIVER ETC     M4183         1X       18.3
# 2      3  W.CAPE-BERGRIVER ETC     EC120         1S       12.0
# 3      4  W.CAPE-BERGRIVER ETC     M4183         1M       18.3
# 4      5  W.CAPE-BERGRIVER ETC     M4183         1L       18.3
#
#               Commodities        Date  Low_Price  High_Price  Sales_Total  \
# 0  APPLE GOLDEN DELICIOUS  2020-07-09      128.0       136.0       5008.0
# 1  APPLE GOLDEN DELICIOUS  2020-01-20      220.0       220.0       1760.0
# 2  APPLE GOLDEN DELICIOUS  2020-08-19      120.0       120.0        720.0
# 3  APPLE GOLDEN DELICIOUS  2020-05-06      160.0       160.0        160.0
# 4  APPLE GOLDEN DELICIOUS  2020-05-04      140.0       160.0      14140.0
#
#    Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand
# 0              38          456.0              0
# ...

# %%
apples_df.dtypes
# Out:
# Province             object
# Container            object
# Size_Grade           object
# Weight_Kg           float64
# Commodities          object
# Date                 object
# Low_Price           float64
# High_Price          float64
# Sales_Total         float64
# Total_Qty_Sold        int64
# Total_Kg_Sold       float64
# Stock_On_Hand         int64
# avg_price_per_kg    float64
# dtype: object

# %%
apples_df['Date'] = pd.to_datetime(apples_df['Date'])
apples_df.dtypes
# Out:
# Province                    object
# Container                   object
# Size_Grade                  object
# Weight_Kg                  float64
# Commodities                 object
# Date                datetime64[ns]
# Low_Price                  float64
# High_Price                 float64
# Sales_Total                float64
# Total_Qty_Sold               int64
# Total_Kg_Sold              float64
# Stock_On_Hand                int64
# avg_price_per_kg           float64
# dtype: object

# %%
test['Date'] = pd.to_datetime(test['Date'])
test.dtypes
# Out:
# Index                      int64
# Province                  object
# Container                 object
# Size_Grade                object
# Weight_Kg                float64
# Commodities               object
# Date              datetime64[ns]
# Low_Price                float64
# High_Price               float64
# Sales_Total              float64
# Total_Qty_Sold             int64
# Total_Kg_Sold            float64
# Stock_On_Hand              int64
# dtype: object

# %%
apples_df = apples_df.sort_values('Date', ascending=True)
plt.plot(apples_df['Date'], apples_df['avg_price_per_kg'])
plt.xticks(rotation='vertical')
# Out:
# (array([18231., 18262., 18293., 18322., 18353., 18383., 18414., 18444.,
#         18475., 18506., 18536.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
apples_df[apples_df['Date'] == '2020-10-03T00:00:00.000000000']
# Out:
#                    Province Container Size_Grade  Weight_Kg  \
# 24034                  CAPE     JE090         2L        9.0
# 10389            WEST COAST     M4183         1L       18.3
# 30425                  CAPE     M4183         1S       18.3
# 60269                  CAPE     JE090         2S        9.0
# 46789                  CAPE     EC120         1S       12.0
# 38819  W.CAPE-BERGRIVER ETC     JE090         2S        9.0
# 10069          EASTERN CAPE     EC120         1M       12.0
# 42418  W.CAPE-BERGRIVER ETC     EC120         1S       12.0
# 32193                 NATAL     EC120         1S       12.0
# 47554            WEST COAST     M4183         1S       18.3
# 41429                  CAPE     M4183         1M       18.3
#
#                   Commodities       Date  Low_Price  High_Price  Sales_Total  \
# 24034  APPLE GOLDEN DELICIOUS 2020-10-03       50.0        70.0      11150.0
# 10389  APPLE GOLDEN DELICIOUS 2020-10-03      150.0       160.0       1590.0
# ...

# %%
# Extract month
apples_df["month"] = apples_df["Date"].dt.month
apples_df.loc[apples_df['month'] == 3,'season'] ='spring'
apples_df.loc[apples_df['month'] == 4,'season'] ='spring'
apples_df.loc[apples_df['month'] == 5,'season'] ='spring'
apples_df.loc[apples_df['month'] == 6,'season'] ='summer'
apples_df.loc[apples_df['month'] == 7,'season'] ='summer'
apples_df.loc[apples_df['month'] == 8,'season'] ='summer'
apples_df.loc[apples_df['month'] == 9,'season'] ='autumn'
apples_df.loc[apples_df['month'] == 10,'season'] ='autumn'
apples_df.loc[apples_df['month'] == 11,'season'] ='autumn'
apples_df.loc[apples_df['month'] == 12,'season'] ='winter'
apples_df.loc[apples_df['month'] == 1,'season'] ='winter'
apples_df.loc[apples_df['month'] == 2,'season'] ='winter'
apples_df
# Out:
#                    Province Container Size_Grade  Weight_Kg  \
# 32221  W.CAPE-BERGRIVER ETC     EC120         1M       12.0
# 30171                 NATAL     IA400         2S      400.0
# 53893                  CAPE     EC120         1L       12.0
# 64177                  CAPE     IA400         1S      400.0
# 35634                  CAPE     M4183         1S       18.3
# ...                     ...       ...        ...        ...
# 10069          EASTERN CAPE     EC120         1M       12.0
# 42418  W.CAPE-BERGRIVER ETC     EC120         1S       12.0
# 32193                 NATAL     EC120         1S       12.0
# 47554            WEST COAST     M4183         1S       18.3
# 41429                  CAPE     M4183         1M       18.3
#
#                   Commodities       Date  Low_Price  High_Price  Sales_Total  \
# 32221  APPLE GOLDEN DELICIOUS 2019-12-11      168.0       168.0       2016.0
# 30171  APPLE GOLDEN DELICIOUS 2019-12-11      500.0       500.0       1500.0
# ...

# %%
# Extract month
test["month"] = test["Date"].dt.month
test.loc[test['month'] == 3,'season'] ='spring'
test.loc[test['month'] == 4,'season'] ='spring'
test.loc[test['month'] == 5,'season'] ='spring'
test.loc[test['month'] == 6,'season'] ='summer'
test.loc[test['month'] == 7,'season'] ='summer'
test.loc[test['month'] == 8,'season'] ='summer'
test.loc[test['month'] == 9,'season'] ='autumn'
test.loc[test['month'] == 10,'season'] ='autumn'
test.loc[test['month'] == 11,'season'] ='autumn'
test.loc[test['month'] == 12,'season'] ='winter'
test.loc[test['month'] == 1,'season'] ='winter'
test.loc[test['month'] == 2,'season'] ='winter'
test
# Out:
#      Index              Province Container Size_Grade  Weight_Kg  \
# 0        1  W.CAPE-BERGRIVER ETC     EC120         1M       12.0
# 1        2  W.CAPE-BERGRIVER ETC     M4183         1X       18.3
# 2        3  W.CAPE-BERGRIVER ETC     EC120         1S       12.0
# 3        4  W.CAPE-BERGRIVER ETC     M4183         1M       18.3
# 4        5  W.CAPE-BERGRIVER ETC     M4183         1L       18.3
# ..     ...                   ...       ...        ...        ...
# 680    681  W.CAPE-BERGRIVER ETC     JE090         2S        9.0
# 681    682                  CAPE     EC120         1M       12.0
# 682    683  W.CAPE-BERGRIVER ETC     JE090         2X        9.0
# 683    684                  CAPE     M4183         1S       18.3
# 684    685                  CAPE     M4183         1S       18.3
#
#                 Commodities       Date  Low_Price  High_Price  Sales_Total  \
# 0    APPLE GOLDEN DELICIOUS 2020-07-09      128.0       136.0       5008.0
# ...

# %% [markdown]
# ### checking for  skewness

# %%
apples_df.skew()
# Out:
# Weight_Kg           3.328254
# Low_Price           4.222672
# High_Price          3.828819
# Sales_Total         4.250317
# Total_Qty_Sold      4.445169
# Total_Kg_Sold       5.529586
# Stock_On_Hand       3.391815
# avg_price_per_kg    0.082452
# month               0.078651
# dtype: float64

# %%
test.skew()
# Out:
# Index             0.000000
# Weight_Kg         3.941111
# Low_Price         4.585123
# High_Price        4.326922
# Sales_Total       3.839600
# Total_Qty_Sold    3.710551
# Total_Kg_Sold     4.270965
# Stock_On_Hand     3.197405
# month             0.194173
# dtype: float64

# %% [markdown]
# ###  log transformation on categorical variables

# %%
cats = ['Weight_Kg', 'Low_Price', 'High_Price', 'Sales_Total', 'Total_Qty_Sold', 'Total_Kg_Sold', 'Stock_On_Hand']
for a in cats:
    apples_df[a] = apples_df[a].map(lambda i: np.log(i) if i > 0 else 0)
    test[a] = test[a].map(lambda i: np.log(i) if i > 0 else 0)

# %%
test.skew()
# Out:
# Index             0.000000
# Weight_Kg         2.995465
# Low_Price         1.631810
# High_Price        1.443425
# Sales_Total      -0.397272
# Total_Qty_Sold   -0.326266
# Total_Kg_Sold    -0.376128
# Stock_On_Hand    -0.648157
# month             0.194173
# dtype: float64

# %%
apples_df.skew()
# Out:
# Weight_Kg           2.624779
# Low_Price           1.141070
# High_Price          1.089270
# Sales_Total        -0.482850
# Total_Qty_Sold     -0.362500
# Total_Kg_Sold      -0.411865
# Stock_On_Hand      -0.511006
# avg_price_per_kg    0.082452
# month               0.078651
# dtype: float64

# %% [markdown]
# ### Removing Outliers

# %%
#Q1 = df.quantile(0.25)
#Q3 = df.quantile(0.75)
#IQR = Q3 - Q1

#apples_df = apples_df[~((apples_df < (Q1 - 1.5 * IQR)) |(apples_df > (Q3 + 1.5 * IQR))).any(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py in _validate_comparison_value(self, other)
#     102             try:
# --> 103                 other = self._validate_listlike(other, opname, allow_object=True)
#     104             except TypeError as err:
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py in _validate_listlike(self, value, opname, cast_str, allow_object)
#     850         elif not type(self)._is_recognized_dtype(value.dtype):
# --> 851             raise TypeError(
#     852                 f"{opname} requires compatible dtype or scalar, "
#
# TypeError: __lt__ requires compatible dtype or scalar, not ndarray
#
# The above exception was the direct cause of the following exception:
#
# InvalidComparison                         Traceback (most recent call last)
# ...

# %% [markdown]
# #### Encoding Categorical variables

# %%
apples_df.isnull().sum()
# Out:
# Province            0
# Container           0
# Size_Grade          0
# Weight_Kg           0
# Low_Price           0
# High_Price          0
# Sales_Total         0
# Total_Qty_Sold      0
# Total_Kg_Sold       0
# Stock_On_Hand       0
# avg_price_per_kg    0
# month               0
# season              0
# dtype: int64

# %%
apples_df.head()
# Out:
#                    Province Container Size_Grade  Weight_Kg  Low_Price  \
# 32221  W.CAPE-BERGRIVER ETC     EC120         1M   2.484907   5.123964
# 30171                 NATAL     IA400         2S   5.991465   6.214608
# 53893                  CAPE     EC120         1L   2.484907   4.605170
# 64177                  CAPE     IA400         1S   5.991465   7.696213
# 35634                  CAPE     M4183         1S   2.906901   5.135798
#
#        High_Price  Sales_Total  Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand  \
# 32221    5.123964     7.608871        2.484907       4.969813       5.820083
# 30171    6.214608     7.313220        1.098612       7.090077       0.000000
# 53893    4.718499     9.422868        4.753590       7.238497       4.330733
# 64177    7.696213    11.097410        3.401197       9.392662       0.000000
# 35634    5.192957     9.638871        4.477337       7.384238       7.065613
#
#        avg_price_per_kg  month  season
# ...

# %%
test.head()
# Out:
#    Index              Province Container Size_Grade  Weight_Kg  Low_Price  \
# 0      1  W.CAPE-BERGRIVER ETC     EC120         1M   2.484907   4.852030
# 1      2  W.CAPE-BERGRIVER ETC     M4183         1X   2.906901   5.393628
# 2      3  W.CAPE-BERGRIVER ETC     EC120         1S   2.484907   4.787492
# 3      4  W.CAPE-BERGRIVER ETC     M4183         1M   2.906901   5.075174
# 4      5  W.CAPE-BERGRIVER ETC     M4183         1L   2.906901   4.941642
#
#    High_Price  Sales_Total  Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand  \
# 0    4.912655     8.518792        3.637586       6.122493       0.000000
# 1    5.393628     7.473069        2.079442       4.986343       0.693147
# 2    4.787492     6.579251        1.791759       4.276666       3.806662
# 3    5.075174     5.075174        0.000000       2.906901       2.079442
# 4    5.075174     9.556763        4.605170       7.512071       2.944439
#
#    month  season
# 0      7  summer
# 1      1  winter
# 2      8  summer
# ...

# %%
test.isnull().sum()
# Out:
# Index             0
# Province          0
# Container         0
# Size_Grade        0
# Weight_Kg         0
# Low_Price         0
# High_Price        0
# Sales_Total       0
# Total_Qty_Sold    0
# Total_Kg_Sold     0
# Stock_On_Hand     0
# month             0
# season            0
# dtype: int64

# %%
apples_df
# Out:
#        Low_Price  High_Price  Sales_Total  Total_Qty_Sold  Total_Kg_Sold  \
# 32221   5.123964    5.123964     7.608871        2.484907       4.969813
# 30171   6.214608    6.214608     7.313220        1.098612       7.090077
# 53893   4.605170    4.718499     9.422868        4.753590       7.238497
# 64177   7.696213    7.696213    11.097410        3.401197       9.392662
# 35634   5.135798    5.192957     9.638871        4.477337       7.384238
# ...          ...         ...          ...             ...            ...
# 10069   4.094345    4.382027     7.712444        3.367296       5.852202
# 42418   4.718499    4.718499     7.976595        3.258097       5.743003
# 32193   4.564348    4.564348     8.723231        4.158883       6.643790
# 47554   4.867534    4.867534     7.170120        2.302585       5.209486
# 41429   4.787492    5.010635     8.484670        3.526361       6.433262
#
#        Stock_On_Hand  avg_price_per_kg  spring  summer  winter
# ...

# %%
test.head()
# Out:
#    Index              Province Container Size_Grade  Weight_Kg  Low_Price  \
# 0      1  W.CAPE-BERGRIVER ETC     EC120         1M   2.484907   4.852030
# 1      2  W.CAPE-BERGRIVER ETC     M4183         1X   2.906901   5.393628
# 2      3  W.CAPE-BERGRIVER ETC     EC120         1S   2.484907   4.787492
# 3      4  W.CAPE-BERGRIVER ETC     M4183         1M   2.906901   5.075174
# 4      5  W.CAPE-BERGRIVER ETC     M4183         1L   2.906901   4.941642
#
#    High_Price  Sales_Total  Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand  \
# 0    4.912655     8.518792        3.637586       6.122493       0.000000
# 1    5.393628     7.473069        2.079442       4.986343       0.693147
# 2    4.787492     6.579251        1.791759       4.276666       3.806662
# 3    5.075174     5.075174        0.000000       2.906901       2.079442
# 4    5.075174     9.556763        4.605170       7.512071       2.944439
#
#    month  season
# 0      7  summer
# 1      1  winter
# 2      8  summer
# ...

# %%
#correlation matrix
heatmap = sns.heatmap(apples_df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
cat_columns = ['Weight_Kg', 'Size_Grade', 'Container', 'Province', 'month', 'season']

# %%
def cat_multcols(allcolumns):
    df_final = apples_df
    i=0
    for fields in allcolumns:
        
        print(fields)
        df1=pd.get_dummies(apples_df[fields],drop_first=True)
        
        apples_df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([apples_df,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([apples_df,df_final],axis=1)
        
    return df_final

# %%
def cattest_multcols(allcolumns):
    df_final = test
    i=0
    for fields in allcolumns:
        
        print(fields)
        df1=pd.get_dummies(test[fields],drop_first=True)
        
        test.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([test,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([test,df_final],axis=1)
        
    return df_final

# %%
apples_df = cat_multcols(cat_columns)
# Out:
# Weight_Kg
# Size_Grade
# Container
# Province
# month
# season

# %%
test = cattest_multcols(cat_columns)
# Out:
# Weight_Kg
# Size_Grade
# Container
# Province
# month
# season

# %%
apples_df.shape
# Out:
# (1952, 17)

# %%
test.shape
# Out:
# (685, 17)

# %%
apples_df =apples_df.loc[:,~apples_df.columns.duplicated()]

# %%
test =test.loc[:,~test.columns.duplicated()]

# %%
#X_train = apples_df.drop(['avg_price_per_kg'], axis=1)
#Y_train = apples_df["avg_price_per_kg"]
x_test  = test.drop("Index", axis=1).copy()
#X_train.shape, Y_train.shape, X_test.shape

# %% [markdown]
# ###  Cross validation

# %%
ridge=Ridge()
params= {'alpha': [5,8,10,10.1,10.2,10.3,10.35,10.36,11,12,15]}
scaler=RobustScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
grid_ridge=GridSearchCV(ridge, param_grid=params,cv=k_fold,scoring='neg_mean_squared_error')
grid_ridge.fit(X_train,y_train)
alpha = grid_ridge.best_params_
ridge_score = grid_ridge.best_score_
print("The best alpha value found is:",alpha['alpha'],'with score:',ridge_score)

ridge_alpha=Ridge(alpha=alpha['alpha'])
ridge_alpha.fit(X_train,y_train)
y_pred_train=ridge_alpha.predict(X_train)
y_pred_test=ridge_alpha.predict(x_test)

print('RMSE train = ',rmsle(y_train,y_pred_train))
print('RMSE test = ',rmsle(y_test,y_pred_test))
# Out:
# The best alpha value found is: 5 with score: -0.8702062408217137
# RMSE train =  0.9001116084585864
# RMSE test =  2.7851250941576073

# %%
# elastic net
# Out:
# [0.67413117 1.05331738 0.79294607 0.94268993 0.77371774 0.69649954
#  0.67756852 0.71583263 0.65709608 0.71240269 0.7038079 ]
# Elasticnet RMSE: 0.7636 (0.1194)

# %% [markdown]
# ### XGboost

# %%
xgb = XGBRegressor(learning_rate= 0.1, n_estimators= 1000, max_depth = 3 , min_child_weight = 3, max_delta_step = 1, subsample = 0.7, random_state=50)
xgb.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=1, max_depth=3,
#              min_child_weight=3, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=4, num_parallel_tree=1, random_state=50,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.7,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred = xgb.predict(X_test)
y_pred
# Out:
# array([ 9.932801  , 12.230704  ,  9.779179  ,  8.58512   ,  7.823943  ,
#         4.5796394 ,  3.8098836 ,  8.27651   ,  8.432919  ,  9.664195  ,
#         4.664656  ,  5.8348703 ,  8.639798  ,  4.145697  ,  4.5284357 ,
#         6.2304263 ,  7.2777224 ,  4.341988  , 10.465792  ,  6.1289973 ,
#         6.1231303 ,  4.6492324 ,  6.0866337 ,  7.833991  ,  5.456652  ,
#         6.646929  ,  7.8300247 ,  8.0216465 ,  7.5366745 ,  7.0980067 ,
#         7.8525734 ,  5.5513616 ,  9.480317  ,  7.69437   ,  4.7493725 ,
#         9.823673  , 10.510864  , 12.125767  ,  6.621354  ,  6.4470778 ,
#         8.378243  ,  7.577646  ,  5.487308  ,  6.237831  ,  5.4405518 ,
#         4.675728  ,  5.070939  ,  5.0942574 ,  6.270991  ,  4.886257  ,
#         1.1581249 ,  6.4039598 ,  6.3492928 , 13.382886  ,  8.333738  ,
#         5.3301105 ,  9.938699  ,  9.563209  ,  8.355077  ,  5.5341234 ,
#         8.465019  , 11.566149  ,  6.444842  ,  9.142922  ,  5.472278  ,
# ...

# %%
# Calculating the accuracy
print("Accuracy:",round(xgb.score(X_train, Y_train)*100,2))
# Out:
# Accuracy: 90.75

# %%
import pickle
file = 'Xgboost_model.pkl'
pickle.dump(xgb, open(file,'wb'))

# %% [markdown]
# ##

# %%
submission = pd.DataFrame({
        "Index": test["Index"],
        "avg_price_per_kg": y_pred
    })
submission.to_csv('submission.csv', index=False)

# %%
submission
# Out:
#      Index  avg_price_per_kg
# 0        1         10.028472
# 1        2         12.374708
# 2        3          9.916717
# 3        4          8.600108
# 4        5          7.706383
# ..     ...               ...
# 680    681          3.467510
# 681    682         10.168788
# 682    683          6.065759
# 683    684          7.356278
# 684    685          7.668357
#
# [685 rows x 2 columns]
